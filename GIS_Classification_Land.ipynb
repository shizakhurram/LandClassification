# %% [markdown]
# <a href="https://colab.research.google.com/github/shizakhurram/LandClassification/blob/main/GIS_Classification_Land.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data_path = "/content/drive/MyDrive/hyperspectral_data/land.zip"
# !unzip {data_path} -d /content/drive/MyDrive/hyperspectral_data/
# Out:
# Archive:  /content/drive/MyDrive/hyperspectral_data/land.zip
#    creating: /content/drive/MyDrive/hyperspectral_data/land/
#    creating: /content/drive/MyDrive/hyperspectral_data/land/desert/
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(10).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(100).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1000).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1001).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1002).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1003).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1004).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1005).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1006).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1007).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1008).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1009).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(101).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1010).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1011).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1012).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1013).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1014).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1015).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1016).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1017).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1018).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1019).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(102).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1020).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1021).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1022).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1023).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1024).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1025).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1026).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1027).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1028).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1029).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(103).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1030).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1031).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1032).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1033).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1034).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1035).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1036).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1037).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1038).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1039).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(104).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1040).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1041).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1042).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1043).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1044).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1045).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1046).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1047).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1048).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1049).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(105).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1050).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1051).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1052).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1053).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1054).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1055).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1056).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1057).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1058).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1059).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(106).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1060).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1061).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1062).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1063).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1064).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1065).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1066).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1067).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1068).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1069).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(107).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1070).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1071).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1072).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1073).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1074).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1075).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1076).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1077).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1078).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1079).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(108).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1080).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1081).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1082).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1083).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1084).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1085).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1086).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1087).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1088).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1089).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(109).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1090).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1091).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(1092).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(11).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(110).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(111).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(112).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(113).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(114).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(115).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(116).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(117).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(118).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(119).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(12).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(120).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(121).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(122).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(123).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(124).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(125).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(126).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(127).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(128).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(129).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(13).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(130).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(131).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(132).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(133).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(134).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(135).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(136).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(137).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(138).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(139).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(14).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(140).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(141).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(142).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(143).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(144).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(145).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(146).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(147).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(148).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(149).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(15).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(150).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(151).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(152).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(153).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(154).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(155).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(156).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(157).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(158).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(159).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(16).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(160).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(161).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(162).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(163).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(164).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(165).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(166).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(167).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(168).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(169).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(17).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(170).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(171).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(172).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(173).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(174).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(175).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(176).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(177).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(178).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(179).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(18).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(180).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(181).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(182).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(183).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(184).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(185).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(186).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(187).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(188).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(189).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(19).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(190).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(191).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(192).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(193).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(194).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(195).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(196).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(197).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(198).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(199).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(2).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(20).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(200).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(201).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(202).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(203).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(204).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(205).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(206).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(207).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(208).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(209).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(21).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(210).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(211).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(212).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(213).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(214).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(215).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(216).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(217).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(218).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(219).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(22).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(220).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(221).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(222).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(223).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(224).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(225).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(226).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(227).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(228).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(229).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(23).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(230).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(231).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(232).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(233).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(234).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(235).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(236).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(237).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(238).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(239).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(24).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(240).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(241).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(242).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(243).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(244).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(245).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(246).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(247).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(248).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(249).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(25).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(250).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(251).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(252).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(253).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(254).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(255).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(256).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(257).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(258).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(259).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(26).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(260).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(261).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(262).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(263).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(264).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(265).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(266).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(267).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(268).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(269).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(27).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(270).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(271).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(272).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(273).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(274).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(275).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(276).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(277).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(278).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(279).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(28).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(280).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(281).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(282).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(283).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(284).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(285).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(286).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(287).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(288).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(289).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(29).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(290).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(291).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(292).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(293).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(294).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(295).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(296).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(297).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(298).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(299).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(3).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(30).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(300).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(301).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(302).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(303).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(304).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(305).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(306).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(307).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(308).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(309).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(31).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(310).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(311).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(312).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(313).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(314).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(315).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(316).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(317).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(318).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(319).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(32).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(320).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(321).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(322).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(323).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(324).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(325).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(326).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(327).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(328).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(329).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(33).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(330).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(331).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(332).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(333).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(334).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(335).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(336).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(337).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(338).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(339).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(34).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(340).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(341).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(342).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(343).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(344).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(345).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(346).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(347).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(348).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(349).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(35).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(350).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(351).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(352).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(353).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(354).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(355).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(356).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(357).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(358).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(359).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(36).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(360).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(361).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(362).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(363).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(364).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(365).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(366).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(367).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(368).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(369).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(37).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(370).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(371).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(372).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(373).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(374).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(375).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(376).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(377).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(378).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(379).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(38).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(380).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(381).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(382).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(383).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(384).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(385).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(386).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(387).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(388).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(389).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(39).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(390).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(391).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(392).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(393).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(394).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(395).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(396).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(397).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(398).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(399).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(4).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(40).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(400).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(401).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(402).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(403).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(404).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(405).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(406).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(407).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(408).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(409).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(41).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(410).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(411).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(412).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(413).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(414).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(415).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(416).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(417).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(418).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(419).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(42).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(420).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(421).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(422).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(423).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(424).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(425).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(426).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(427).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(428).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(429).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(43).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(430).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(431).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(432).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(433).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(434).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(435).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(436).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(437).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(438).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(439).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(44).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(440).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(441).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(442).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(443).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(444).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(445).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(446).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(447).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(448).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(449).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(45).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(450).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(451).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(452).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(453).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(454).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(455).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(456).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(457).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(458).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(459).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(46).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(460).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(461).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(462).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(463).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(464).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(465).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(466).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(467).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(468).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(469).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(47).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(470).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(471).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(472).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(473).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(474).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(475).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(476).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(477).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(478).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(479).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(48).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(480).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(481).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(482).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(483).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(484).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(485).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(486).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(487).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(488).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(489).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(49).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(490).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(491).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(492).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(493).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(494).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(495).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(496).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(497).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(498).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(499).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(5).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(50).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(500).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(501).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(502).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(503).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(504).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(505).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(506).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(507).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(508).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(509).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(51).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(510).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(511).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(512).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(513).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(514).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(515).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(516).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(517).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(518).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(519).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(52).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/desert/desert(520).tif
# ...
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(854).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(855).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(856).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(857).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(858).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(859).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(86).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(860).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(861).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(862).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(863).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(864).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(865).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(866).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(867).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(868).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(869).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(87).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(870).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(871).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(872).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(873).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(874).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(875).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(876).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(877).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(878).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(879).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(88).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(880).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(881).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(882).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(883).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(884).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(885).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(886).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(887).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(888).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(889).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(89).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(890).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(891).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(892).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(893).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(894).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(895).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(896).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(897).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(898).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(899).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(9).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(90).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(900).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(901).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(902).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(903).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(904).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(905).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(906).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(907).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(908).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(909).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(91).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(910).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(911).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(912).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(913).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(914).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(915).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(916).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(917).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(918).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(919).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(92).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(920).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(921).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(922).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(923).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(924).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(925).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(926).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(927).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(928).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(929).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(93).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(930).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(931).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(932).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(933).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(934).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(935).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(936).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(937).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(938).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(939).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(94).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(940).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(941).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(942).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(943).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(944).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(945).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(946).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(947).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(948).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(949).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(95).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(950).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(951).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(952).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(953).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(954).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(955).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(956).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(957).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(958).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(959).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(96).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(960).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(961).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(962).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(963).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(964).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(965).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(966).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(967).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(968).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(969).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(97).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(970).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(971).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(972).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(973).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(974).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(975).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(976).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(977).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(978).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(979).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(98).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(980).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(981).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(982).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(983).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(984).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(985).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(986).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(987).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(988).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(989).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(99).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(990).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(991).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(992).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(993).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(994).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(995).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(996).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(997).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(998).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/land/snow_mountain/snow_mountain(999).tif

# %%
EXTRACTED_DATA_PATH = "/content/drive/MyDrive/hyperspectral_data/land"
TRAIN_SIZE = 0.7
VAL_SIZE = 0.15
TEST_SIZE = 0.15
BATCH_SIZE = 32
EPOCHS = 3

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

full_dataset = datasets.ImageFolder(root=EXTRACTED_DATA_PATH, transform=transform)
class_names = full_dataset.classes
print(f"Classes found: {class_names}")
# Out:
# Classes found: ['desert', 'mountain', 'sandbeach', 'snow_mountain']

# %%
class_counts = []
for dir in os.listdir(EXTRACTED_DATA_PATH):
  class_counts.append(len(os.listdir(os.path.join(EXTRACTED_DATA_PATH, dir))))

# %%
def plot_class_distribution(dataset, class_names):

    plt.figure(figsize=(8, 5))
    sns.barplot(x=class_names, y=class_counts, palette='viridis')
    plt.title("Class Distribution in Dataset")
    plt.ylabel("Number of Images")
    plt.xlabel("Classes")
    plt.show()

plot_class_distribution(full_dataset, class_names)
# Out:
# <ipython-input-10-a5ce7d6f2e3d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=class_counts, palette='viridis')

# %%
from torchvision.utils import make_grid
from torchvision.transforms.functional import to_pil_image

def show_sample_images(dataset, class_names, samples_per_class=3):
    """Display sample images from each class efficiently."""
    # ⚡ Check if dataset has 'targets' for quick indexing
    targets = dataset.targets if hasattr(dataset, 'targets') else [label for _, label in dataset]

    fig, axes = plt.subplots(len(class_names), samples_per_class, figsize=(samples_per_class * 3, len(class_names) * 3))
    fig.suptitle("Sample Images from Each Class", fontsize=16)

    for cls_idx, cls_name in enumerate(class_names):
        # ✅ Quickly find indices without scanning entire dataset
        class_indices = [i for i, t in enumerate(targets) if t == cls_idx][:samples_per_class]

        for j, img_idx in enumerate(class_indices):
            img, _ = dataset[img_idx]
            # ⚡ Faster un-normalization for display
            img = img * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1) + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
            img = torch.clamp(img, 0, 1)  # Clip values for valid range
            axes[cls_idx, j].imshow(img.permute(1, 2, 0).cpu().numpy())
            axes[cls_idx, j].axis('off')
            if j == 0:
                axes[cls_idx, j].set_ylabel(cls_name, rotation=0, labelpad=50, fontsize=12)

    plt.tight_layout()
    plt.show()

# 🚀 Run optimized function
show_sample_images(full_dataset, class_names)

# %%
total_size = len(full_dataset)
train_size = int(TRAIN_SIZE * total_size)
val_size = int(VAL_SIZE * total_size)
test_size = total_size - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

# %%
batch_size = BATCH_SIZE
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class CNNClassifier(nn.Module):
    def __init__(self, num_classes=3):
        super(CNNClassifier, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 32 * 32, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
model = CNNClassifier(num_classes=len(class_names)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 🎯 Training and validation function
def train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS):
    best_val_acc = 0.0
    train_acc_list, val_acc_list, train_loss_list, val_loss_list = [], [], [], []
    for epoch in range(epochs):
        print(epoch)
        model.train()
        total_loss, correct, total = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = correct / total
        train_acc_list.append(train_acc)
        train_loss_list.append(total_loss / len(train_loader))

        val_acc, val_loss = evaluate_model(model, val_loader, criterion)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)

        print(f"Epoch [{epoch+1}/{epochs}] - Loss: {total_loss:.4f} - Train Acc: {train_acc:.4f} - Val Acc: {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), f'best_model_{model_name}.pth')

    return train_acc_list, val_acc_list, train_loss_list, val_loss_list

# %%
def evaluate_model(model, data_loader, criterion):
    model.eval()
    correct, total, total_loss = 0, 0, 0
    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total, total_loss / len(data_loader)

# %%
# 📊 Confusion Matrix visualization
def analyze_model(model, data_loader, model_name):
    y_true, y_pred = [], []
    model.eval()
    with torch.no_grad():
        for images, labels in data_loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    cm = confusion_matrix(y_true, y_pred, normalize='true')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, values_format=".2f")
    plt.title(f"Normalized Confusion Matrix - {model_name}")
    plt.show()

# %%
# 🏃‍♂️ Plot training analysis
def plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name):
    epochs = range(1, len(train_acc) + 1)
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    axs[0].plot(epochs, train_acc, 'bo-', label='Training Acc')
    axs[0].plot(epochs, val_acc, 'ro-', label='Validation Acc')
    axs[0].set_title(f'{model_name}: Accuracy per Epoch')
    axs[0].legend()

    axs[1].plot(epochs, train_loss, 'bo-', label='Training Loss')
    axs[1].plot(epochs, val_loss, 'ro-', label='Validation Loss')
    axs[1].set_title(f'{model_name}: Loss per Epoch')
    axs[1].legend()

    plt.show()

# %%
def get_pretrained_model(model_name, num_classes):
    if model_name == 'resnet50':
        model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'densenet121':
        model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'efficientnet_b0':
        model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
        num_ftrs = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    else:
        raise ValueError(f"Unsupported model: {model_name}")

    # Freeze feature extractor
    for param in model.parameters():
        param.requires_grad = False

    # Only classifier layers are trainable
    for param in model.fc.parameters() if hasattr(model, 'fc') else model.classifier.parameters():
        param.requires_grad = True

    return model.to(device)

# %%
# 🚀 Compare models
models_to_compare = ['custom', 'densenet121', 'efficientnet_b0','resnet50']
results = {}

for model_name in models_to_compare:
    print(f"\n🚀 Training model: {model_name}")
    if model_name == 'custom':
      model = CNNClassifier(num_classes=len(class_names)).to(device)
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(model.parameters(), lr=0.001)
      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
      model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
      test_acc, _ = evaluate_model(model, test_loader, criterion)
      print(f"✅ Test Accuracy ({model_name}): {test_acc:.4f}")
      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}
    else:
      model = get_pretrained_model(model_name, num_classes=len(class_names))
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
      model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
      test_acc, _ = evaluate_model(model, test_loader, criterion)
      print(f"✅ Test Accuracy ({model_name}): {test_acc:.4f}")

      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}

# 🏆 Final Test Accuracy Summary
for model_name, result in results.items():
    print(f"🏅 {model_name} - Final Test Accuracy: {result['test_acc']:.4f}")
# Out:
# 🚀 Training model: custom
# 0
# Epoch [1/3] - Loss: 17.3193 - Train Acc: 0.9264 - Val Acc: 0.9424
# 1
# Epoch [2/3] - Loss: 6.9390 - Train Acc: 0.9706 - Val Acc: 0.9814
# 2
# Epoch [3/3] - Loss: 3.1940 - Train Acc: 0.9829 - Val Acc: 0.9851
# <ipython-input-25-94ed3bc2314c>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (custom): 0.9944
# 🚀 Training model: densenet121
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 196MB/s]
# 0
# Epoch [1/3] - Loss: 41.0937 - Train Acc: 0.8497 - Val Acc: 0.9740
# 1
# Epoch [2/3] - Loss: 11.6535 - Train Acc: 0.9718 - Val Acc: 0.9833
# 2
# Epoch [3/3] - Loss: 8.0971 - Train Acc: 0.9801 - Val Acc: 0.9907
# <ipython-input-25-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (densenet121): 0.9870
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 🚀 Training model: efficientnet_b0
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 131MB/s]
# 0
# Epoch [1/3] - Loss: 38.0840 - Train Acc: 0.8767 - Val Acc: 0.9777
# 1
# Epoch [2/3] - Loss: 14.5484 - Train Acc: 0.9586 - Val Acc: 0.9814
# 2
# Epoch [3/3] - Loss: 11.5808 - Train Acc: 0.9654 - Val Acc: 0.9814
# <ipython-input-25-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (efficientnet_b0): 0.9796
# 🚀 Training model: resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 202MB/s]
# 0
# Epoch [1/3] - Loss: 42.4682 - Train Acc: 0.8903 - Val Acc: 0.9740
# 1
# Epoch [2/3] - Loss: 14.9056 - Train Acc: 0.9658 - Val Acc: 0.9777
# 2
# Epoch [3/3] - Loss: 10.1285 - Train Acc: 0.9746 - Val Acc: 0.9777
# <ipython-input-25-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (resnet50): 0.9889
# 🏅 custom - Final Test Accuracy: 0.9944
# 🏅 densenet121 - Final Test Accuracy: 0.9870
# 🏅 efficientnet_b0 - Final Test Accuracy: 0.9796
# 🏅 resnet50 - Final Test Accuracy: 0.9889
