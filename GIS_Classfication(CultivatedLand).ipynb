# %% [markdown]
# <a href="https://colab.research.google.com/github/shizakhurram/LandClassification/blob/main/GIS_Classfication(CultivatedLand).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data_path = "/content/drive/MyDrive/hyperspectral_data/cultivatedland.zip"
# !unzip {data_path} -d /content/drive/MyDrive/hyperspectral_data/
# Out:
# Archive:  /content/drive/MyDrive/hyperspectral_data/cultivatedland.zip
#    creating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/
#    creating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(1).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(10).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(100).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(101).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(102).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(103).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(104).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(105).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(106).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(107).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(108).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(109).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(11).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(110).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(111).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(112).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(113).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(114).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(115).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(116).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(117).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(118).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(119).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(12).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(120).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(121).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(122).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(123).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(124).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(125).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(126).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(127).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(128).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(129).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(13).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(130).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(131).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(132).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(133).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(134).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(135).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(136).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(137).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(138).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(139).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(14).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(140).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(141).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(142).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(143).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(144).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(145).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(146).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(147).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(148).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(149).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(15).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(150).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(151).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(152).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(153).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(154).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(155).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(156).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(157).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(158).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(159).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(16).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(160).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(161).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(162).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(163).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(164).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(165).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(166).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(167).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(168).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(169).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(17).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(170).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(171).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(172).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(173).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(174).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(175).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(176).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(177).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(178).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(179).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(18).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(180).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(181).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(182).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(183).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(184).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(185).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(186).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(187).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(188).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(189).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(19).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(190).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(191).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(192).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(193).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(194).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(195).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(196).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(197).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(198).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(199).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(2).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(20).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(200).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(201).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(202).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(203).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(204).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(205).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(206).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(207).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(208).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(209).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(21).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(210).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(211).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(212).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(213).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(214).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(215).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(216).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(217).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(218).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(219).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(22).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(220).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(221).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(222).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(223).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(224).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(225).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(226).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(227).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(228).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(229).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(23).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(230).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(231).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(232).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(233).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(234).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(235).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(236).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(237).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(238).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(239).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(24).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(240).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(241).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(242).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(243).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(244).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(245).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(246).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(247).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(248).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(249).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(25).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(250).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(251).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(252).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(253).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(254).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(255).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(256).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(257).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(258).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(259).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(26).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(260).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(261).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(262).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(263).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(264).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(265).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(266).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(267).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(268).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(269).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(27).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(270).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(271).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(272).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(273).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(274).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(275).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(276).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(277).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(278).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(279).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(28).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(280).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(281).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(282).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(283).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(284).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(285).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(286).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(287).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(288).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(289).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(29).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(290).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(291).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(292).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(293).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(294).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(295).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(296).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(297).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(298).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(299).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(3).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(30).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(300).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(301).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(302).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(303).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(304).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(305).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(306).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(307).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(308).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(309).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(31).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(310).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(311).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(312).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(313).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(314).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(315).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(316).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(317).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(318).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(319).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(32).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(320).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(321).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(322).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(323).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(324).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(325).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(326).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(327).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(328).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(329).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(33).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(330).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(331).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(332).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(333).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(334).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(335).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(336).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(337).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(338).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(339).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(34).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(340).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(341).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(342).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(343).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(344).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(345).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(346).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(347).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(348).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(349).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(35).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(350).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(351).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(352).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(353).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(354).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(355).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(356).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(357).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(358).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(359).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(36).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(360).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(361).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(362).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(363).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(364).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(365).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(366).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(367).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(368).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(369).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(37).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(370).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(371).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(372).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(373).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(374).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(375).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(376).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(377).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(378).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(379).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(38).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(380).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(381).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(382).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(383).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(384).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(385).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(386).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(387).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(388).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(389).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(39).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(390).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(391).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(392).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(393).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(394).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(395).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(396).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(397).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(398).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(399).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(4).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(40).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(400).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(401).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(402).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(403).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(404).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(405).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(406).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(407).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(408).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(409).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(41).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(410).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(411).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(412).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(413).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(414).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(415).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(416).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(417).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(418).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(419).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(42).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(420).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(421).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(422).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(423).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(424).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(425).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(426).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(427).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(428).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(429).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(43).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(430).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(431).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(432).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(433).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(434).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(435).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(436).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(437).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(438).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(439).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(44).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(440).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(441).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(442).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(443).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(444).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(445).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(446).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(447).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(448).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(449).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(45).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(450).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(451).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(452).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(453).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(454).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(455).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(456).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(457).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(458).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(459).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(46).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(460).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(461).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(462).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(463).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(464).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(465).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(466).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(467).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(468).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(469).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(47).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(470).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(471).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(472).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(473).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(474).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(475).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(476).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(477).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(478).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(479).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(48).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(480).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(481).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(482).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(483).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(484).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(485).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(486).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(487).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(488).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(489).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(49).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(490).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(491).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(492).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(493).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(494).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(495).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(496).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(497).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(498).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(499).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(5).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(50).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(500).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(501).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(502).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(503).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(504).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(505).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(506).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(507).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(508).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(509).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(51).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(510).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(511).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(512).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(513).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(514).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(515).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(516).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(517).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(518).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(519).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(52).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(520).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(521).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(522).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(523).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/bare_land/bare_land(524).tif
# ...
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(55).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(550).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(551).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(552).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(553).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(554).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(555).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(556).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(557).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(558).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(559).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(56).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(560).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(561).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(562).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(563).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(564).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(565).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(566).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(567).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(568).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(569).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(57).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(570).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(571).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(572).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(573).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(574).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(575).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(576).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(577).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(578).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(579).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(58).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(580).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(581).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(582).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(583).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(584).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(585).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(586).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(587).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(588).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(589).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(59).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(590).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(591).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(592).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(593).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(594).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(595).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(596).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(597).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(598).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(599).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(6).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(60).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(600).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(601).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(602).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(603).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(604).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(605).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(606).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(607).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(608).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(609).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(61).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(610).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(611).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(612).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(613).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(614).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(615).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(616).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(617).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(618).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(619).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(62).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(620).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(621).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(622).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(623).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(624).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(625).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(626).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(627).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(628).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(629).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(63).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(630).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(631).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(632).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(633).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(634).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(635).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(636).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(637).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(638).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(639).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(64).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(640).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(641).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(642).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(643).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(644).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(65).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(66).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(67).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(68).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(69).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(7).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(70).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(71).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(72).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(73).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(74).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(75).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(76).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(77).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(78).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(79).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(8).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(80).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(81).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(82).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(83).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(84).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(85).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(86).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(87).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(88).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(89).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(9).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(90).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(91).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(92).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(93).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(94).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(95).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(96).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(97).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(98).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/cultivatedland/green_farmland/green_farmland(99).tif

# %%
EXTRACTED_DATA_PATH = "/content/drive/MyDrive/hyperspectral_data/cultivatedland"
TRAIN_SIZE = 0.7
VAL_SIZE = 0.15
TEST_SIZE = 0.15
BATCH_SIZE = 32
EPOCHS = 10

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

full_dataset = datasets.ImageFolder(root=EXTRACTED_DATA_PATH, transform=transform)
class_names = full_dataset.classes
print(f"Classes found: {class_names}")
# Out:
# Classes found: ['bare_land', 'dry_farm', 'green_farmland']

# %%
class_counts = []
for dir in os.listdir(EXTRACTED_DATA_PATH):
  class_counts.append(len(os.listdir(os.path.join(EXTRACTED_DATA_PATH, dir))))

# %%
def plot_class_distribution(dataset, class_names):

    plt.figure(figsize=(8, 5))
    sns.barplot(x=class_names, y=class_counts, palette='viridis')
    plt.title("Class Distribution in Dataset")
    plt.ylabel("Number of Images")
    plt.xlabel("Classes")
    plt.show()

plot_class_distribution(full_dataset, class_names)
# Out:
# <ipython-input-6-a5ce7d6f2e3d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=class_counts, palette='viridis')

# %%
from torchvision.utils import make_grid
from torchvision.transforms.functional import to_pil_image

def show_sample_images(dataset, class_names, samples_per_class=3):
    """Display sample images from each class efficiently."""
    # ⚡ Check if dataset has 'targets' for quick indexing
    targets = dataset.targets if hasattr(dataset, 'targets') else [label for _, label in dataset]

    fig, axes = plt.subplots(len(class_names), samples_per_class, figsize=(samples_per_class * 3, len(class_names) * 3))
    fig.suptitle("Sample Images from Each Class", fontsize=16)

    for cls_idx, cls_name in enumerate(class_names):
        # ✅ Quickly find indices without scanning entire dataset
        class_indices = [i for i, t in enumerate(targets) if t == cls_idx][:samples_per_class]

        for j, img_idx in enumerate(class_indices):
            img, _ = dataset[img_idx]
            # ⚡ Faster un-normalization for display
            img = img * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1) + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
            img = torch.clamp(img, 0, 1)  # Clip values for valid range
            axes[cls_idx, j].imshow(img.permute(1, 2, 0).cpu().numpy())
            axes[cls_idx, j].axis('off')
            if j == 0:
                axes[cls_idx, j].set_ylabel(cls_name, rotation=0, labelpad=50, fontsize=12)

    plt.tight_layout()
    plt.show()

# 🚀 Run optimized function
show_sample_images(full_dataset, class_names)

# %%
total_size = len(full_dataset)
train_size = int(TRAIN_SIZE * total_size)
val_size = int(VAL_SIZE * total_size)
test_size = total_size - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

# %%
batch_size = BATCH_SIZE
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class CNNClassifier(nn.Module):
    def __init__(self, num_classes=3):
        super(CNNClassifier, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 32 * 32, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
model = CNNClassifier(num_classes=len(class_names)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 🎯 Training and validation function
def train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS):
    best_val_acc = 0.0
    train_acc_list, val_acc_list, train_loss_list, val_loss_list = [], [], [], []
    for epoch in range(epochs):
        print(epoch)
        model.train()
        total_loss, correct, total = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = correct / total
        train_acc_list.append(train_acc)
        train_loss_list.append(total_loss / len(train_loader))

        val_acc, val_loss = evaluate_model(model, val_loader, criterion)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)

        print(f"Epoch [{epoch+1}/{epochs}] - Loss: {total_loss:.4f} - Train Acc: {train_acc:.4f} - Val Acc: {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), f'best_model_{model_name}.pth')

    return train_acc_list, val_acc_list, train_loss_list, val_loss_list

# %%
def evaluate_model(model, data_loader, criterion):
    model.eval()
    correct, total, total_loss = 0, 0, 0
    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total, total_loss / len(data_loader)

# %%
# 📊 Confusion Matrix visualization
def analyze_model(model, data_loader, model_name):
    y_true, y_pred = [], []
    model.eval()
    with torch.no_grad():
        for images, labels in data_loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    cm = confusion_matrix(y_true, y_pred, normalize='true')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, values_format=".2f")
    plt.title(f"Normalized Confusion Matrix - {model_name}")
    plt.show()

# %%
# 🏃‍♂️ Plot training analysis
def plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name):
    epochs = range(1, len(train_acc) + 1)
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    axs[0].plot(epochs, train_acc, 'bo-', label='Training Acc')
    axs[0].plot(epochs, val_acc, 'ro-', label='Validation Acc')
    axs[0].set_title(f'{model_name}: Accuracy per Epoch')
    axs[0].legend()

    axs[1].plot(epochs, train_loss, 'bo-', label='Training Loss')
    axs[1].plot(epochs, val_loss, 'ro-', label='Validation Loss')
    axs[1].set_title(f'{model_name}: Loss per Epoch')
    axs[1].legend()

    plt.show()

# %%
def get_pretrained_model(model_name, num_classes):
    if model_name == 'resnet50':
        model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'densenet121':
        model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'efficientnet_b0':
        model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
        num_ftrs = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    else:
        raise ValueError(f"Unsupported model: {model_name}")

    # Freeze feature extractor
    for param in model.parameters():
        param.requires_grad = False

    # Only classifier layers are trainable
    for param in model.fc.parameters() if hasattr(model, 'fc') else model.classifier.parameters():
        param.requires_grad = True

    return model.to(device)

# %%
# 🚀 Compare models
models_to_compare = ['custom', 'densenet121', 'efficientnet_b0','resnet50']
results = {}

for model_name in models_to_compare:
    print(f"\n🚀 Training model: {model_name}")
    if model_name == 'custom':
      model = CNNClassifier(num_classes=len(class_names)).to(device)
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(model.parameters(), lr=0.001)
      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
      model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
      test_acc, _ = evaluate_model(model, test_loader, criterion)
      print(f"✅ Test Accuracy ({model_name}): {test_acc:.4f}")
      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}
    else:
      model = get_pretrained_model(model_name, num_classes=len(class_names))
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
      model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
      test_acc, _ = evaluate_model(model, test_loader, criterion)
      print(f"✅ Test Accuracy ({model_name}): {test_acc:.4f}")

      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}

# 🏆 Final Test Accuracy Summary
for model_name, result in results.items():
    print(f"🏅 {model_name} - Final Test Accuracy: {result['test_acc']:.4f}")
# Out:
# 🚀 Training model: custom
# 0
# Epoch [1/10] - Loss: 19.6110 - Train Acc: 0.8919 - Val Acc: 0.9787
# 1
# Epoch [2/10] - Loss: 5.5975 - Train Acc: 0.9691 - Val Acc: 0.9976
# 2
# Epoch [3/10] - Loss: 3.6747 - Train Acc: 0.9802 - Val Acc: 0.9929
# 3
# Epoch [4/10] - Loss: 2.5082 - Train Acc: 0.9878 - Val Acc: 0.9882
# 4
# Epoch [5/10] - Loss: 1.9949 - Train Acc: 0.9883 - Val Acc: 0.9953
# 5
# Epoch [6/10] - Loss: 1.9613 - Train Acc: 0.9863 - Val Acc: 0.9976
# 6
# Epoch [7/10] - Loss: 6.5614 - Train Acc: 0.9726 - Val Acc: 0.9526
# 7
# Epoch [8/10] - Loss: 2.0385 - Train Acc: 0.9873 - Val Acc: 0.9905
# 8
# Epoch [9/10] - Loss: 2.5756 - Train Acc: 0.9883 - Val Acc: 0.9953
# 9
# Epoch [10/10] - Loss: 1.5662 - Train Acc: 0.9883 - Val Acc: 0.9976
# <ipython-input-22-94ed3bc2314c>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (custom): 0.9953
# 🚀 Training model: densenet121
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 156MB/s]
# 0
# Epoch [1/10] - Loss: 20.9354 - Train Acc: 0.9072 - Val Acc: 0.9882
# 1
# Epoch [2/10] - Loss: 4.8043 - Train Acc: 0.9868 - Val Acc: 0.9953
# 2
# Epoch [3/10] - Loss: 3.5434 - Train Acc: 0.9888 - Val Acc: 0.9976
# 3
# Epoch [4/10] - Loss: 3.0749 - Train Acc: 0.9873 - Val Acc: 0.9953
# 4
# Epoch [5/10] - Loss: 2.3340 - Train Acc: 0.9924 - Val Acc: 0.9976
# 5
# Epoch [6/10] - Loss: 1.9797 - Train Acc: 0.9934 - Val Acc: 0.9976
# 6
# Epoch [7/10] - Loss: 1.7572 - Train Acc: 0.9939 - Val Acc: 0.9976
# 7
# Epoch [8/10] - Loss: 2.1259 - Train Acc: 0.9919 - Val Acc: 1.0000
# 8
# Epoch [9/10] - Loss: 1.5114 - Train Acc: 0.9944 - Val Acc: 0.9976
# 9
# Epoch [10/10] - Loss: 1.1894 - Train Acc: 0.9959 - Val Acc: 1.0000
# <ipython-input-22-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (densenet121): 0.9976
# 🚀 Training model: efficientnet_b0
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 63.2MB/s]
# 0
# Epoch [1/10] - Loss: 23.3835 - Train Acc: 0.9077 - Val Acc: 0.9882
# 1
# Epoch [2/10] - Loss: 8.1317 - Train Acc: 0.9731 - Val Acc: 0.9858
# 2
# Epoch [3/10] - Loss: 6.6725 - Train Acc: 0.9706 - Val Acc: 0.9905
# 3
# Epoch [4/10] - Loss: 5.1189 - Train Acc: 0.9736 - Val Acc: 0.9858
# 4
# Epoch [5/10] - Loss: 3.8703 - Train Acc: 0.9838 - Val Acc: 0.9882
# 5
# Epoch [6/10] - Loss: 3.3542 - Train Acc: 0.9863 - Val Acc: 0.9882
# 6
# Epoch [7/10] - Loss: 3.9406 - Train Acc: 0.9833 - Val Acc: 0.9858
# 7
# Epoch [8/10] - Loss: 2.6453 - Train Acc: 0.9899 - Val Acc: 0.9882
# 8
# Epoch [9/10] - Loss: 2.5984 - Train Acc: 0.9904 - Val Acc: 0.9929
# 9
# Epoch [10/10] - Loss: 2.1257 - Train Acc: 0.9914 - Val Acc: 0.9882
# <ipython-input-22-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (efficientnet_b0): 0.9976
# 🚀 Training model: resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 167MB/s]
# 0
# Epoch [1/10] - Loss: 20.8514 - Train Acc: 0.9198 - Val Acc: 0.9929
# 1
# Epoch [2/10] - Loss: 6.4026 - Train Acc: 0.9797 - Val Acc: 0.9953
# 2
# Epoch [3/10] - Loss: 4.3336 - Train Acc: 0.9863 - Val Acc: 0.9976
# 3
# Epoch [4/10] - Loss: 3.2105 - Train Acc: 0.9893 - Val Acc: 0.9953
# 4
# Epoch [5/10] - Loss: 3.1884 - Train Acc: 0.9878 - Val Acc: 0.9953
# 5
# Epoch [6/10] - Loss: 2.4137 - Train Acc: 0.9924 - Val Acc: 0.9976
# 6
# Epoch [7/10] - Loss: 2.6498 - Train Acc: 0.9893 - Val Acc: 0.9976
# 7
# Epoch [8/10] - Loss: 2.2004 - Train Acc: 0.9929 - Val Acc: 0.9976
# 8
# Epoch [9/10] - Loss: 1.4869 - Train Acc: 0.9975 - Val Acc: 0.9976
# 9
# Epoch [10/10] - Loss: 1.6124 - Train Acc: 0.9949 - Val Acc: 0.9976
# <ipython-input-22-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (resnet50): 0.9953
# 🏅 custom - Final Test Accuracy: 0.9953
# 🏅 densenet121 - Final Test Accuracy: 0.9976
# 🏅 efficientnet_b0 - Final Test Accuracy: 0.9976
# 🏅 resnet50 - Final Test Accuracy: 0.9953
