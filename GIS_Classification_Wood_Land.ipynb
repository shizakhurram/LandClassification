# %% [markdown]
# <a href="https://colab.research.google.com/github/shizakhurram/LandClassification/blob/main/GIS_Classification_Wood_Land.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data_path = "/content/drive/MyDrive/hyperspectral_data/woodland.zip"
# !unzip {data_path} -d /content/drive/MyDrive/hyperspectral_data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(907).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(908).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(909).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(91).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(910).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(911).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(912).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(913).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(914).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(915).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(916).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(917).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(918).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(919).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(92).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(920).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(921).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(922).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(923).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(924).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(925).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(926).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(927).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(928).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(929).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(93).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(930).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(931).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(932).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(933).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(934).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(935).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(936).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(937).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(938).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(939).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(94).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(940).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(941).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(942).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(943).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(944).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(945).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(946).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(947).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(948).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(949).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(95).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(950).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(951).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(952).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(953).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(954).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(955).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(956).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(957).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(958).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(959).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(96).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(960).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(961).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(962).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(963).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(964).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(965).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(966).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(967).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(968).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(969).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(97).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(970).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(971).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(972).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(973).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(974).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(975).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(976).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(977).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(978).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(979).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(98).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(980).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(981).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(982).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(983).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(984).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(985).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(986).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(987).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(988).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(989).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(99).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(990).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(991).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(992).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(993).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(994).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(995).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(996).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(997).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(998).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/forest/forest(999).tif
#    creating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(10).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(100).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1000).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1001).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1002).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1003).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1004).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1005).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1006).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1007).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1008).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1009).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(101).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1010).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1011).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1012).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1013).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1014).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1015).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1016).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1017).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1018).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1019).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(102).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1020).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1021).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1022).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1023).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1024).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1025).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1026).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1027).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1028).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1029).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(103).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1030).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1031).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1032).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1033).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1034).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1035).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1036).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1037).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1038).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1039).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(104).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1040).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1041).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1042).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1043).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1044).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1045).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1046).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1047).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1048).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(1049).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(105).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(106).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(107).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(108).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(109).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(11).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(110).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(111).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(112).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(113).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(114).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(115).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(116).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(117).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(118).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(119).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(12).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(120).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(121).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(122).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(123).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(124).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(125).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(126).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(127).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(128).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(129).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(13).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(130).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(131).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(132).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(133).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(134).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(135).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(136).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(137).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(138).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(139).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(14).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(140).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(141).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(142).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(143).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(144).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(145).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(146).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(147).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(148).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(149).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(15).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(150).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(151).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(152).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(153).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(154).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(155).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(156).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(157).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(158).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(159).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(16).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(160).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(161).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(162).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(163).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(164).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(165).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(166).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(167).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(168).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(169).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(17).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(170).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(171).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(172).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(173).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(174).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(175).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(176).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(177).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(178).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(179).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(18).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(180).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(181).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(182).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(183).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(184).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(185).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(186).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(187).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(188).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(189).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(19).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(190).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(191).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(192).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(193).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(194).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(195).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(196).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(197).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(198).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(199).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(2).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(20).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(200).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(201).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(202).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(203).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(204).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(205).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(206).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(207).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(208).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(209).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(21).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(210).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(211).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(212).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(213).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(214).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(215).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(216).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(217).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(218).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(219).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(22).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(220).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(221).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(222).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(223).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(224).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(225).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(226).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(227).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(228).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(229).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(23).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(230).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(231).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(232).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(233).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(234).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(235).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(236).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(237).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(238).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(239).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(24).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(240).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(241).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(242).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(243).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(244).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(245).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(246).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(247).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(248).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(249).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(25).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(250).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(251).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(252).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(253).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(254).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(255).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(256).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(257).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(258).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(259).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(26).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(260).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(261).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(262).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(263).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(264).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(265).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(266).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(267).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(268).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(269).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(27).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(270).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(271).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(272).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(273).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(274).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(275).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(276).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(277).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(278).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(279).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(28).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(280).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(281).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(282).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(283).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(284).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(285).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(286).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(287).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(288).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(289).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(29).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(290).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(291).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(292).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(293).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(294).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(295).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(296).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(297).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(298).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(299).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(3).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(30).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(300).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(301).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(302).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(303).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(304).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(305).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(306).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(307).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(308).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(309).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(31).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(310).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(311).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(312).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(313).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(314).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(315).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(316).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(317).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(318).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(319).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(32).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(320).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(321).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(322).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(323).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(324).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(325).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(326).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(327).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(328).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(329).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(33).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(330).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(331).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(332).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(333).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(334).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(335).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(336).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(337).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(338).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(339).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(34).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(340).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(341).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(342).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(343).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(344).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(345).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(346).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(347).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(348).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(349).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(35).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(350).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(351).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(352).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(353).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(354).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(355).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(356).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(357).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(358).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(359).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(36).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(360).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(361).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(362).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(363).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(364).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(365).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(366).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(367).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(368).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(369).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(37).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(370).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(371).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(372).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(373).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(374).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(375).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(376).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(377).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(378).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(379).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(38).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(380).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(381).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(382).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(383).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(384).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(385).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(386).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(387).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(388).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(389).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(39).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(390).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(391).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(392).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(393).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(394).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(395).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(396).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(397).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(398).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(399).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(4).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(40).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(400).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(401).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(402).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(403).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(404).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(405).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(406).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(407).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(408).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(409).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(41).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(410).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(411).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(412).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(413).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(414).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(415).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(416).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(417).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(418).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(419).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(42).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(420).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(421).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(422).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(423).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(424).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(425).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(426).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(427).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(428).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/mangrove/mangrove(429).tif
# ...
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(86).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(860).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(861).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(862).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(863).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(864).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(865).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(866).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(867).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(868).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(869).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(87).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(870).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(871).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(872).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(873).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(874).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(875).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(876).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(877).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(878).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(879).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(88).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(880).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(881).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(882).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(883).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(884).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(885).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(886).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(887).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(888).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(889).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(89).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(890).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(891).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(892).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(893).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(894).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(895).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(896).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(897).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(898).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(899).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(9).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(90).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(900).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(901).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(902).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(903).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(904).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(905).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(906).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(907).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(908).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(909).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(91).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(910).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(911).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(912).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(913).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(914).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(915).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(916).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(917).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(918).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(919).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(92).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(920).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(921).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(922).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(923).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(924).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(925).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(926).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(927).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(928).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(929).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(93).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(930).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(931).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(932).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(933).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(934).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(935).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(936).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(937).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(938).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(939).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(94).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(940).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(941).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(942).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(943).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(944).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(945).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(946).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(947).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(948).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(949).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(95).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(950).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(951).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(952).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(953).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(954).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(955).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(956).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(957).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(958).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(959).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(96).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(960).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(961).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(962).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(963).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(964).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(965).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(966).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(967).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(968).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(969).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(97).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(970).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(971).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(972).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(973).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(974).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(975).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(976).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(977).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(978).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(979).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(98).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(980).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(981).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(982).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(983).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(984).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(985).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(986).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(987).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(988).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(989).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(99).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(990).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(991).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(992).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(993).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(994).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(995).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(996).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(997).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(998).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/woodland/sparse_forest/sparse_forest(999).tif

# %%
EXTRACTED_DATA_PATH = "/content/drive/MyDrive/hyperspectral_data/woodland"
TRAIN_SIZE = 0.7
VAL_SIZE = 0.15
TEST_SIZE = 0.15
BATCH_SIZE = 32
EPOCHS = 10

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

full_dataset = datasets.ImageFolder(root=EXTRACTED_DATA_PATH, transform=transform)
class_names = full_dataset.classes
print(f"Classes found: {class_names}")
# Out:
# Classes found: ['artificial_grassland', 'forest', 'mangrove', 'river_protection_forest', 'sapling', 'shrubwood', 'sparse_forest']

# %%
class_counts = []
for dir in os.listdir(EXTRACTED_DATA_PATH):
  class_counts.append(len(os.listdir(os.path.join(EXTRACTED_DATA_PATH, dir))))

# %%
def plot_class_distribution(dataset, class_names):

    plt.figure(figsize=(8, 5))
    sns.barplot(x=class_names, y=class_counts, palette='viridis')
    plt.title("Class Distribution in Dataset")
    plt.ylabel("Number of Images")
    plt.xlabel("Classes")
    plt.show()

plot_class_distribution(full_dataset, class_names)
# Out:
# <ipython-input-6-a5ce7d6f2e3d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=class_counts, palette='viridis')

# %%
from torchvision.utils import make_grid
from torchvision.transforms.functional import to_pil_image

def show_sample_images(dataset, class_names, samples_per_class=3):
    """Display sample images from each class efficiently."""
    # ⚡ Check if dataset has 'targets' for quick indexing
    targets = dataset.targets if hasattr(dataset, 'targets') else [label for _, label in dataset]

    fig, axes = plt.subplots(len(class_names), samples_per_class, figsize=(samples_per_class * 3, len(class_names) * 3))
    fig.suptitle("Sample Images from Each Class", fontsize=16)

    for cls_idx, cls_name in enumerate(class_names):
        # ✅ Quickly find indices without scanning entire dataset
        class_indices = [i for i, t in enumerate(targets) if t == cls_idx][:samples_per_class]

        for j, img_idx in enumerate(class_indices):
            img, _ = dataset[img_idx]
            # ⚡ Faster un-normalization for display
            img = img * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1) + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
            img = torch.clamp(img, 0, 1)  # Clip values for valid range
            axes[cls_idx, j].imshow(img.permute(1, 2, 0).cpu().numpy())
            axes[cls_idx, j].axis('off')
            if j == 0:
                axes[cls_idx, j].set_ylabel(cls_name, rotation=0, labelpad=50, fontsize=12)

    plt.tight_layout()
    plt.show()

# 🚀 Run optimized function
show_sample_images(full_dataset, class_names)

# %%
total_size = len(full_dataset)
train_size = int(TRAIN_SIZE * total_size)
val_size = int(VAL_SIZE * total_size)
test_size = total_size - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

# %%
batch_size = BATCH_SIZE
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class CNNClassifier(nn.Module):
    def __init__(self, num_classes=3):
        super(CNNClassifier, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 32 * 32, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
model = CNNClassifier(num_classes=len(class_names)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 🎯 Training and validation function
def train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS):
    best_val_acc = 0.0
    train_acc_list, val_acc_list, train_loss_list, val_loss_list = [], [], [], []
    for epoch in range(epochs):
        print(epoch)
        model.train()
        total_loss, correct, total = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = correct / total
        train_acc_list.append(train_acc)
        train_loss_list.append(total_loss / len(train_loader))

        val_acc, val_loss = evaluate_model(model, val_loader, criterion)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)

        print(f"Epoch [{epoch+1}/{epochs}] - Loss: {total_loss:.4f} - Train Acc: {train_acc:.4f} - Val Acc: {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), f'best_model_{model_name}.pth')

    return train_acc_list, val_acc_list, train_loss_list, val_loss_list

# %%
def evaluate_model(model, data_loader, criterion):
    model.eval()
    correct, total, total_loss = 0, 0, 0
    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total, total_loss / len(data_loader)

# %%
# 📊 Confusion Matrix visualization
def analyze_model(model, data_loader, model_name):
    y_true, y_pred = [], []
    model.eval()
    with torch.no_grad():
        for images, labels in data_loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    cm = confusion_matrix(y_true, y_pred, normalize='true')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, values_format=".2f")
    plt.title(f"Normalized Confusion Matrix - {model_name}")
    plt.show()

# %%
# 🏃‍♂️ Plot training analysis
def plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name):
    epochs = range(1, len(train_acc) + 1)
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    axs[0].plot(epochs, train_acc, 'bo-', label='Training Acc')
    axs[0].plot(epochs, val_acc, 'ro-', label='Validation Acc')
    axs[0].set_title(f'{model_name}: Accuracy per Epoch')
    axs[0].legend()

    axs[1].plot(epochs, train_loss, 'bo-', label='Training Loss')
    axs[1].plot(epochs, val_loss, 'ro-', label='Validation Loss')
    axs[1].set_title(f'{model_name}: Loss per Epoch')
    axs[1].legend()

    plt.show()

# %%
def get_pretrained_model(model_name, num_classes):
    if model_name == 'resnet50':
        model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'densenet121':
        model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'efficientnet_b0':
        model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
        num_ftrs = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    else:
        raise ValueError(f"Unsupported model: {model_name}")

    # Freeze feature extractor
    for param in model.parameters():
        param.requires_grad = False

    # Only classifier layers are trainable
    for param in model.fc.parameters() if hasattr(model, 'fc') else model.classifier.parameters():
        param.requires_grad = True

    return model.to(device)

# %%
# 🚀 Compare models
models_to_compare = ['custom', 'densenet121', 'efficientnet_b0','resnet50']
results = {}

for model_name in models_to_compare:
    print(f"\n🚀 Training model: {model_name}")
    if model_name == 'custom':
      model = CNNClassifier(num_classes=len(class_names)).to(device)
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(model.parameters(), lr=0.001)
      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
      model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
      test_acc, _ = evaluate_model(model, test_loader, criterion)
      print(f"✅ Test Accuracy ({model_name}): {test_acc:.4f}")
      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}
    else:
      model = get_pretrained_model(model_name, num_classes=len(class_names))
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
      model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
      test_acc, _ = evaluate_model(model, test_loader, criterion)
      print(f"✅ Test Accuracy ({model_name}): {test_acc:.4f}")

      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}

# 🏆 Final Test Accuracy Summary
for model_name, result in results.items():
    print(f"🏅 {model_name} - Final Test Accuracy: {result['test_acc']:.4f}")
# Out:
# 🚀 Training model: custom
# 0
# Epoch [1/10] - Loss: 156.1000 - Train Acc: 0.5795 - Val Acc: 0.8156
# 1
# Epoch [2/10] - Loss: 68.7583 - Train Acc: 0.8155 - Val Acc: 0.9072
# 2
# Epoch [3/10] - Loss: 48.7209 - Train Acc: 0.8733 - Val Acc: 0.9360
# 3
# Epoch [4/10] - Loss: 27.3654 - Train Acc: 0.9297 - Val Acc: 0.9488
# 4
# Epoch [5/10] - Loss: 24.7469 - Train Acc: 0.9388 - Val Acc: 0.9499
# 5
# Epoch [6/10] - Loss: 18.3610 - Train Acc: 0.9564 - Val Acc: 0.9680
# 6
# Epoch [7/10] - Loss: 19.4693 - Train Acc: 0.9502 - Val Acc: 0.9627
# 7
# Epoch [8/10] - Loss: 17.7443 - Train Acc: 0.9514 - Val Acc: 0.9638
# 8
# Epoch [9/10] - Loss: 14.1860 - Train Acc: 0.9637 - Val Acc: 0.9510
# 9
# Epoch [10/10] - Loss: 18.4797 - Train Acc: 0.9527 - Val Acc: 0.9670
# <ipython-input-17-94ed3bc2314c>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (custom): 0.9681
# 🚀 Training model: densenet121
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 182MB/s]
# 0
# Epoch [1/10] - Loss: 73.2443 - Train Acc: 0.8831 - Val Acc: 0.9851
# 1
# Epoch [2/10] - Loss: 17.5922 - Train Acc: 0.9831 - Val Acc: 0.9915
# 2
# Epoch [3/10] - Loss: 10.5030 - Train Acc: 0.9900 - Val Acc: 0.9915
# 3
# Epoch [4/10] - Loss: 8.6739 - Train Acc: 0.9886 - Val Acc: 0.9904
# 4
# Epoch [5/10] - Loss: 6.4662 - Train Acc: 0.9934 - Val Acc: 0.9936
# 5
# Epoch [6/10] - Loss: 5.1632 - Train Acc: 0.9934 - Val Acc: 0.9925
# 6
# Epoch [7/10] - Loss: 5.1077 - Train Acc: 0.9925 - Val Acc: 0.9936
# 7
# Epoch [8/10] - Loss: 4.1179 - Train Acc: 0.9954 - Val Acc: 0.9904
# 8
# Epoch [9/10] - Loss: 3.3449 - Train Acc: 0.9970 - Val Acc: 0.9915
# 9
# Epoch [10/10] - Loss: 4.0291 - Train Acc: 0.9932 - Val Acc: 0.9925
# <ipython-input-17-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (densenet121): 0.9947
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 🚀 Training model: efficientnet_b0
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 160MB/s]
# 0
# Epoch [1/10] - Loss: 75.4044 - Train Acc: 0.8735 - Val Acc: 0.9851
# 1
# Epoch [2/10] - Loss: 25.4560 - Train Acc: 0.9605 - Val Acc: 0.9861
# 2
# Epoch [3/10] - Loss: 18.5993 - Train Acc: 0.9689 - Val Acc: 0.9893
# 3
# Epoch [4/10] - Loss: 15.5547 - Train Acc: 0.9710 - Val Acc: 0.9925
# 4
# Epoch [5/10] - Loss: 13.3057 - Train Acc: 0.9751 - Val Acc: 0.9904
# 5
# Epoch [6/10] - Loss: 11.1670 - Train Acc: 0.9779 - Val Acc: 0.9893
# 6
# Epoch [7/10] - Loss: 12.4419 - Train Acc: 0.9742 - Val Acc: 0.9947
# 7
# Epoch [8/10] - Loss: 10.9102 - Train Acc: 0.9781 - Val Acc: 0.9925
# 8
# Epoch [9/10] - Loss: 10.7679 - Train Acc: 0.9758 - Val Acc: 0.9925
# 9
# Epoch [10/10] - Loss: 9.8518 - Train Acc: 0.9799 - Val Acc: 0.9947
# <ipython-input-17-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (efficientnet_b0): 0.9936
# 🚀 Training model: resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 163MB/s]
# 0
# Epoch [1/10] - Loss: 76.3238 - Train Acc: 0.8934 - Val Acc: 0.9744
# 1
# Epoch [2/10] - Loss: 20.6571 - Train Acc: 0.9804 - Val Acc: 0.9872
# 2
# Epoch [3/10] - Loss: 13.9326 - Train Acc: 0.9829 - Val Acc: 0.9851
# 3
# Epoch [4/10] - Loss: 10.5162 - Train Acc: 0.9874 - Val Acc: 0.9861
# 4
# Epoch [5/10] - Loss: 7.9383 - Train Acc: 0.9902 - Val Acc: 0.9893
# 5
# Epoch [6/10] - Loss: 6.7413 - Train Acc: 0.9925 - Val Acc: 0.9925
# 6
# Epoch [7/10] - Loss: 5.4027 - Train Acc: 0.9932 - Val Acc: 0.9893
# 7
# Epoch [8/10] - Loss: 5.1344 - Train Acc: 0.9945 - Val Acc: 0.9915
# 8
# Epoch [9/10] - Loss: 4.4053 - Train Acc: 0.9938 - Val Acc: 0.9904
# 9
# Epoch [10/10] - Loss: 4.2987 - Train Acc: 0.9950 - Val Acc: 0.9936
# <ipython-input-17-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (resnet50): 0.9957
# 🏅 custom - Final Test Accuracy: 0.9681
# 🏅 densenet121 - Final Test Accuracy: 0.9947
# 🏅 efficientnet_b0 - Final Test Accuracy: 0.9936
# 🏅 resnet50 - Final Test Accuracy: 0.9957
