# %% [markdown]
# <a href="https://colab.research.google.com/github/shizakhurram/LandClassification/blob/main/GIS_Classification_WaterAreas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data_path = "/content/drive/MyDrive/hyperspectral_data/waterarea.zip"
# !unzip {data_path} -d /content/drive/MyDrive/hyperspectral_data/
# Out:
# Archive:  /content/drive/MyDrive/hyperspectral_data/waterarea.zip
#    creating: /content/drive/MyDrive/hyperspectral_data/waterarea/
#    creating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(1).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(10).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(100).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(101).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(102).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(103).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(104).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(105).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(106).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(107).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(108).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(109).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(11).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(110).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(111).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(112).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(113).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(114).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(115).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(116).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(117).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(118).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(119).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(12).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(120).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(121).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(122).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(123).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(124).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(125).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(126).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(127).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(128).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(129).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(13).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(130).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(131).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(132).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(133).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(134).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(135).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(136).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(137).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(138).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(139).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(14).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(140).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(141).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(142).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(143).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(144).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(145).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(146).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(147).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(148).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(149).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(15).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(150).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(151).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(152).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(153).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(154).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(155).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(156).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(157).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(158).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(159).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(16).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(160).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(161).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(162).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(163).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(164).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(165).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(166).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(167).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(168).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(169).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(17).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(170).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(171).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(172).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(173).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(174).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(175).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(176).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(177).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(178).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(179).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(18).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(180).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(181).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(182).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(183).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(184).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(185).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(186).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(187).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(188).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(189).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(19).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(190).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(191).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(192).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(193).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(194).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(195).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(196).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(197).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(198).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(199).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(2).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(20).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(200).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(201).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(202).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(203).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(204).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(205).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(206).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(207).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(208).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(209).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(21).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(210).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(211).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(212).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(213).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(214).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(215).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(216).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(217).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(218).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(219).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(22).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(220).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(221).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(222).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(223).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(224).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(225).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(226).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(227).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(228).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(229).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(23).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(230).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(231).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(232).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(233).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(234).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(235).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(236).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(237).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(238).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(239).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(24).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(240).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(241).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(242).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(243).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(244).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(245).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(246).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(247).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(248).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(249).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(25).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(250).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(251).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(252).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(253).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(254).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(255).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(256).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(257).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(258).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(259).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(26).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(260).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(261).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(262).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(263).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(264).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(265).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(266).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(267).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(268).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(269).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(27).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(270).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(271).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(272).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(273).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(274).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(275).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(276).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(277).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(278).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(279).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(28).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(280).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(281).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(282).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(283).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(284).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(285).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(286).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(287).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(288).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(289).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(29).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(290).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(291).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(292).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(293).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(294).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(295).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(296).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(297).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(298).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(299).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(3).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(30).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(300).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(301).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(302).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(303).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(304).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(305).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(306).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(307).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(308).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(309).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(31).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(310).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(311).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(312).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(313).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(314).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(315).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(316).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(317).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(318).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(319).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(32).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(320).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(321).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(322).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(323).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(324).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(325).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(326).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(327).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(328).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(329).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(33).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(330).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(331).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(332).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(333).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(334).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(335).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(336).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(337).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(338).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(339).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(34).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(340).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(341).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(342).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(343).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(344).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(345).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(346).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(347).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(348).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(349).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(35).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(350).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(351).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(352).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(353).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(354).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(355).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(356).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(357).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(358).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(359).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(36).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(360).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(361).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(362).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(363).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(364).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(365).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(366).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(367).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(368).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(369).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(37).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(370).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(371).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(372).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(373).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(374).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(375).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(376).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(377).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(378).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(379).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(38).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(380).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(381).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(382).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(383).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(384).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(385).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(386).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(387).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(388).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(389).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(39).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(390).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(391).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(392).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(393).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(394).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(395).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(396).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(397).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(398).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(399).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(4).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(40).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(400).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(401).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(402).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(403).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(404).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(405).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(406).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(407).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(408).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(409).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(41).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(410).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(411).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(412).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(413).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(414).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(415).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(416).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(417).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(418).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(419).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(42).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(420).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(421).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(422).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(423).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(424).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(425).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(426).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(427).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(428).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(429).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(43).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(430).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(431).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(432).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(433).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(434).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(435).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(436).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(437).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(438).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(439).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(44).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(440).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(441).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(442).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(443).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(444).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(445).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(446).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(447).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(448).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(449).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(45).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(450).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(451).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(452).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(453).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(454).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(455).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(456).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(457).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(458).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(459).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(46).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(47).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(48).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(49).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(5).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(50).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(51).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(52).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(53).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(54).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(55).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(56).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(57).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(58).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(59).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(6).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(60).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(61).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(62).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(63).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(64).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(65).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(66).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(67).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(68).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(69).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(7).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(70).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(71).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(72).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(73).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(74).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(75).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(76).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(77).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(78).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(79).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(8).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(80).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(81).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(82).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(83).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(84).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(85).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(86).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(87).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(88).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(89).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(9).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(90).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(91).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(92).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(93).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(94).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(95).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(96).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(97).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(98).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/coastline/coastline(99).tif
#    creating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(1).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(10).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(100).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(101).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(102).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(103).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(104).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(105).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(106).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(107).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(108).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(109).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(11).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(110).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(111).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(112).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(113).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(114).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(115).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(116).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(117).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(118).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(119).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(12).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(120).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(121).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(122).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(123).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(124).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(125).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(126).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(127).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(128).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(129).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(13).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(130).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(131).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(132).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(133).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(134).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(135).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(136).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(137).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/dam/dam(138).tif
# ...
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(559).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(56).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(560).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(561).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(562).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(563).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(564).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(565).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(566).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(567).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(568).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(569).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(57).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(570).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(571).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(572).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(573).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(574).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(575).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(576).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(577).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(578).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(579).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(58).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(580).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(581).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(582).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(583).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(584).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(585).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(586).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(587).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(588).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(589).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(59).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(590).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(591).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(592).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(593).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(594).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(595).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(596).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(597).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(598).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(599).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(6).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(60).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(600).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(601).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(602).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(603).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(604).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(605).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(606).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(607).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(608).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(609).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(61).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(610).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(611).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(612).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(613).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(614).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(615).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(616).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(617).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(618).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(619).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(62).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(620).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(621).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(622).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(623).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(624).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(625).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(626).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(627).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(628).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(629).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(63).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(630).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(631).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(632).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(633).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(634).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(635).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(636).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(637).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(638).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(639).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(64).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(640).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(641).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(642).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(643).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(644).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(645).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(646).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(647).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(648).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(649).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(65).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(650).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(651).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(652).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(653).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(654).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(655).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(656).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(657).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(658).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(659).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(66).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(660).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(661).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(662).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(663).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(664).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(665).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(666).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(667).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(668).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(669).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(67).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(670).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(671).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(672).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(673).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(674).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(675).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(676).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(677).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(678).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(679).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(68).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(680).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(681).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(682).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(683).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(684).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(685).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(686).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(687).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(688).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(69).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(7).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(70).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(71).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(72).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(73).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(74).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(75).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(76).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(77).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(78).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(79).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(8).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(80).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(81).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(82).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(83).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(84).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(85).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(86).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(87).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(88).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(89).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(9).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(90).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(91).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(92).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(93).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(94).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(95).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(96).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(97).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(98).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/waterarea/stream/stream(99).tif

# %%
EXTRACTED_DATA_PATH = "/content/drive/MyDrive/hyperspectral_data/waterarea"
TRAIN_SIZE = 0.7
VAL_SIZE = 0.15
TEST_SIZE = 0.15
BATCH_SIZE = 32
EPOCHS = 3

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

full_dataset = datasets.ImageFolder(root=EXTRACTED_DATA_PATH, transform=transform)
class_names = full_dataset.classes
print(f"Classes found: {class_names}")
# Out:
# Classes found: ['coastline', 'dam', 'hirst', 'lakeshore', 'river', 'sea', 'stream']

# %%
class_counts = []
for dir in os.listdir(EXTRACTED_DATA_PATH):
  class_counts.append(len(os.listdir(os.path.join(EXTRACTED_DATA_PATH, dir))))

# %%
def plot_class_distribution(dataset, class_names):

    plt.figure(figsize=(8, 5))
    sns.barplot(x=class_names, y=class_counts, palette='viridis')
    plt.title("Class Distribution in Dataset")
    plt.ylabel("Number of Images")
    plt.xlabel("Classes")
    plt.show()

plot_class_distribution(full_dataset, class_names)
# Out:
# <ipython-input-20-a5ce7d6f2e3d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=class_counts, palette='viridis')

# %%
from torchvision.utils import make_grid
from torchvision.transforms.functional import to_pil_image

def show_sample_images(dataset, class_names, samples_per_class=3):
    """Display sample images from each class efficiently."""
    # ⚡ Check if dataset has 'targets' for quick indexing
    targets = dataset.targets if hasattr(dataset, 'targets') else [label for _, label in dataset]

    fig, axes = plt.subplots(len(class_names), samples_per_class, figsize=(samples_per_class * 3, len(class_names) * 3))
    fig.suptitle("Sample Images from Each Class", fontsize=16)

    for cls_idx, cls_name in enumerate(class_names):
        # ✅ Quickly find indices without scanning entire dataset
        class_indices = [i for i, t in enumerate(targets) if t == cls_idx][:samples_per_class]

        for j, img_idx in enumerate(class_indices):
            img, _ = dataset[img_idx]
            # ⚡ Faster un-normalization for display
            img = img * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1) + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
            img = torch.clamp(img, 0, 1)  # Clip values for valid range
            axes[cls_idx, j].imshow(img.permute(1, 2, 0).cpu().numpy())
            axes[cls_idx, j].axis('off')
            if j == 0:
                axes[cls_idx, j].set_ylabel(cls_name, rotation=0, labelpad=50, fontsize=12)

    plt.tight_layout()
    plt.show()

# 🚀 Run optimized function
show_sample_images(full_dataset, class_names)

# %%
total_size = len(full_dataset)
train_size = int(TRAIN_SIZE * total_size)
val_size = int(VAL_SIZE * total_size)
test_size = total_size - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

# %%
batch_size = BATCH_SIZE
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class CNNClassifier(nn.Module):
    def __init__(self, num_classes=3):
        super(CNNClassifier, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 32 * 32, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
model = CNNClassifier(num_classes=len(class_names)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 🎯 Training and validation function
def train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS):
    best_val_acc = 0.0
    train_acc_list, val_acc_list, train_loss_list, val_loss_list = [], [], [], []
    for epoch in range(epochs):
        model.train()
        total_loss, correct, total = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = correct / total
        train_acc_list.append(train_acc)
        train_loss_list.append(total_loss / len(train_loader))

        val_acc, val_loss = evaluate_model(model, val_loader, criterion)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)

        print(f"Epoch [{epoch+1}/{epochs}] - Loss: {total_loss:.4f} - Train Acc: {train_acc:.4f} - Val Acc: {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), f'best_model_{model_name}.pth')

    return train_acc_list, val_acc_list, train_loss_list, val_loss_list

# %%
def evaluate_model(model, data_loader, criterion):
    model.eval()
    correct, total, total_loss = 0, 0, 0
    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total, total_loss / len(data_loader)

# %%
# 📊 Confusion Matrix visualization
def analyze_model(model, data_loader, model_name):
    y_true, y_pred = [], []
    model.eval()
    with torch.no_grad():
        for images, labels in data_loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    cm = confusion_matrix(y_true, y_pred, normalize='true')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, values_format=".2f")
    plt.title(f"Normalized Confusion Matrix - {model_name}")
    plt.show()

# %%
# 🏃‍♂️ Plot training analysis
def plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name):
    epochs = range(1, len(train_acc) + 1)
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    axs[0].plot(epochs, train_acc, 'bo-', label='Training Acc')
    axs[0].plot(epochs, val_acc, 'ro-', label='Validation Acc')
    axs[0].set_title(f'{model_name}: Accuracy per Epoch')
    axs[0].legend()

    axs[1].plot(epochs, train_loss, 'bo-', label='Training Loss')
    axs[1].plot(epochs, val_loss, 'ro-', label='Validation Loss')
    axs[1].set_title(f'{model_name}: Loss per Epoch')
    axs[1].legend()

    plt.show()

# %%
def get_pretrained_model(model_name, num_classes):
    if model_name == 'resnet50':
        model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'densenet121':
        model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'efficientnet_b0':
        model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
        num_ftrs = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    else:
        raise ValueError(f"Unsupported model: {model_name}")

    # Freeze feature extractor
    for param in model.parameters():
        param.requires_grad = False

    # Only classifier layers are trainable
    for param in model.fc.parameters() if hasattr(model, 'fc') else model.classifier.parameters():
        param.requires_grad = True

    return model.to(device)

# %%
# 🚀 Compare models
models_to_compare = ['resnet50', 'densenet121', 'efficientnet_b0','custom']
results = {}

for model_name in models_to_compare:
    print(f"\n🚀 Training model: {model_name}")
    if model_name == 'custom':
      model = CNNClassifier(num_classes=len(class_names)).to(device)
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(model.parameters(), lr=0.001)
      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}
      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
    else:
      model = get_pretrained_model(model_name, num_classes=len(class_names))
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
      model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
      test_acc, _ = evaluate_model(model, test_loader, criterion)
      print(f"✅ Test Accuracy ({model_name}): {test_acc:.4f}")

      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}

# 🏆 Final Test Accuracy Summary
for model_name, result in results.items():
    print(f"🏅 {model_name} - Final Test Accuracy: {result['test_acc']:.4f}")
# Out:
# 🚀 Training model: resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 121MB/s]
# Epoch [1/3] - Loss: 77.2770 - Train Acc: 0.8297 - Val Acc: 0.9187
# Epoch [2/3] - Loss: 29.0548 - Train Acc: 0.9474 - Val Acc: 0.9496
# Epoch [3/3] - Loss: 19.3046 - Train Acc: 0.9652 - Val Acc: 0.9528
# <ipython-input-31-147f40d5d2f3>:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (resnet50): 0.9741
# 🚀 Training model: densenet121
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 103MB/s]
# Epoch [1/3] - Loss: 66.0742 - Train Acc: 0.8047 - Val Acc: 0.9285
# Epoch [2/3] - Loss: 20.6446 - Train Acc: 0.9506 - Val Acc: 0.9398
# Epoch [3/3] - Loss: 14.8164 - Train Acc: 0.9648 - Val Acc: 0.9463
# <ipython-input-31-147f40d5d2f3>:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (densenet121): 0.9611
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 🚀 Training model: efficientnet_b0
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 147MB/s]
# Epoch [1/3] - Loss: 72.8125 - Train Acc: 0.8064 - Val Acc: 0.9398
# Epoch [2/3] - Loss: 25.9605 - Train Acc: 0.9429 - Val Acc: 0.9577
# Epoch [3/3] - Loss: 20.8889 - Train Acc: 0.9474 - Val Acc: 0.9512
# <ipython-input-31-147f40d5d2f3>:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (efficientnet_b0): 0.9530
# 🚀 Training model: custom
# Epoch [1/3] - Loss: 76.0456 - Train Acc: 0.7131 - Val Acc: 0.8455
# Epoch [2/3] - Loss: 31.1916 - Train Acc: 0.8830 - Val Acc: 0.9073
# Epoch [3/3] - Loss: 21.6710 - Train Acc: 0.9231 - Val Acc: 0.8894
# 🏅 resnet50 - Final Test Accuracy: 0.9741
# 🏅 densenet121 - Final Test Accuracy: 0.9611
# 🏅 efficientnet_b0 - Final Test Accuracy: 0.9530
# 🏅 custom - Final Test Accuracy: 0.9530
